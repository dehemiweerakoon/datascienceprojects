# %%
import requests
from bs4 import BeautifulSoup
from csv import writer
from time import sleep
from random import choice
import pandas as pd

# %%
all_quotes = []
base_url = "https://quotes.toscrape.com/"

url ="/page/1"

while url:
  res = requests.get(f"{base_url}{url}")
  print(f"Now scraping {base_url}{url}")
  soup = BeautifulSoup(res.text,"html.parser")

  quotes = soup.find_all(class_="quote")

  for quote in quotes:
    all_quotes.append({
        "text":quote.find(class_="text").get_text(),
        "autor":quote.find(class_="author").get_text(),
        "bio-link":quote.find('a')['href']
    })

  next_btn = soup.find(class_="next")
  url = next_btn.find('a')["href"] if next_btn else None
  sleep(2)

quote = choice(all_quotes)
print(quote)
# Out:
# Now scraping https://quotes.toscrape.com//page/1
# Now scraping https://quotes.toscrape.com//page/2/
# Now scraping https://quotes.toscrape.com//page/3/
# Now scraping https://quotes.toscrape.com//page/4/
# Now scraping https://quotes.toscrape.com//page/5/
# Now scraping https://quotes.toscrape.com//page/6/
# Now scraping https://quotes.toscrape.com//page/7/
# Now scraping https://quotes.toscrape.com//page/8/
# Now scraping https://quotes.toscrape.com//page/9/
# Now scraping https://quotes.toscrape.com//page/10/
# {'text': '“Not all of us can do great things. But we can do small things with great love.”', 'autor': 'Mother Teresa', 'bio-link': '/author/Mother-Teresa'}

# %%
df=pd.DataFrame.from_dict(all_quotes,orient='columns')

# %%
df
# Out:
#                                                  text               autor  \
# 0   “The world as we have created it is a process ...     Albert Einstein
# 1   “It is our choices, Harry, that show what we t...        J.K. Rowling
# 2   “There are only two ways to live your life. On...     Albert Einstein
# 3   “The person, be it gentleman or lady, who has ...         Jane Austen
# 4   “Imperfection is beauty, madness is genius and...      Marilyn Monroe
# ..                                                ...                 ...
# 95  “You never really understand a person until yo...          Harper Lee
# 96  “You have to write the book that wants to be w...   Madeleine L'Engle
# 97  “Never tell the truth to people who are not wo...          Mark Twain
# 98        “A person's a person, no matter how small.”           Dr. Seuss
# 99  “... a mind needs books as a sword needs a whe...  George R.R. Martin
#
#                      bio-link
# 0     /author/Albert-Einstein
# 1         /author/J-K-Rowling
# 2     /author/Albert-Einstein
# 3         /author/Jane-Austen
# 4      /author/Marilyn-Monroe
# ..                        ...
# 95         /author/Harper-Lee
# 96   /author/Madeleine-LEngle
# 97         /author/Mark-Twain
# 98           /author/Dr-Seuss
# 99  /author/George-R-R-Martin
#
# [100 rows x 3 columns]

# %%
df['text']=df['text'].str.replace('“','')

# %%
df.to_csv('quotes.csv',index=False)
